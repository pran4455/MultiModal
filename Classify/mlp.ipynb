# %%
import wfdb
import numpy as np
import pandas as pd
import scipy.signal
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, hamming_loss, multilabel_confusion_matrix
from sklearn.preprocessing import StandardScaler
import os

# Constants - MATCHING ORIGINAL
LABELS = ["H", "HA", "OA", "X", "CA", "CAA", "L", "LA", "A", "W", "1", "2", "3", "4", "R"]
DATA_DIR = "../data/"
WINDOW_SIZE = 30  # seconds

def read_signals(record_name):
    """Read signals and metadata from record"""
    try:
        rec_path = os.path.join(DATA_DIR, record_name)
        record = wfdb.rdrecord(rec_path)
        return record.p_signal, record.sig_name, record.fs
    except Exception as e:
        print(f"Error reading {record_name}: {str(e)}")
        return None, None, None

def extract_features(signal, fs):
    """ORIGINAL FEATURE SET - only basic features"""
    features = {}
    
    # Basic time-domain features
    features['mean'] = np.mean(signal)
    features['std'] = np.std(signal)
    features['max'] = np.max(signal)
    features['min'] = np.min(signal)
    
    # Frequency-domain feature (same as original)
    try:
        f, psd = scipy.signal.welch(signal, fs=fs)
        features['power'] = np.sum(psd)
    except:
        features['power'] = 0
    
    return features

def process_record(record_name, window_size=WINDOW_SIZE):
    """Process a single record into features and labels"""
    signals, signal_names, fs = read_signals(record_name)
    if signals is None:
        return None
    
    segment_length = fs * window_size
    annotation = wfdb.rdann(record_name, 'st')
    
    data = []
    labels = []
    
    for i in range(0, len(signals), segment_length):
        segment = signals[i:i+segment_length]
        if len(segment) == 0:
            continue
            
        segment_features = {}
        for j, sig_name in enumerate(signal_names):
            sig = segment[:, j]
            features = extract_features(sig, fs)
            for stat_name, stat_val in features.items():
                segment_features[f"{sig_name}_{stat_name}"] = stat_val
        
        # Label processing
        segment_labels = {label: 0 for label in LABELS}
        for ann_time, ann_note in zip(annotation.sample, annotation.aux_note):
            if i <= ann_time < i + segment_length:
                for label in LABELS:
                    if label in ann_note:
                        segment_labels[label] = 1
        
        data.append(segment_features)
        labels.append(segment_labels)
    
    return pd.DataFrame(data), pd.DataFrame(labels)

record_names = [
    "slp01a", "slp01b", "slp02a", "slp02b", "slp03", "slp04",
    "slp14", "slp16", "slp32", "slp37", "slp41", "slp45",
    "slp48", "slp59", "slp60", "slp61", "slp66", "slp67x"
]

# Process all records
dfs = []
for record in record_names:
    rec_path = os.path.join(DATA_DIR, record)
    print(f"Processing {record}...")
    df_features, df_labels = process_record(rec_path)
    if df_features is not None:
        df = pd.concat([df_features, df_labels], axis=1)
        df.to_csv(f"{record}_features.csv", index=False)
        dfs.append(df)

# Combine all data
df_all = pd.concat(dfs, ignore_index=True)

# Minimal NaN handling - only drop rows with all NaN
print(f"\nOriginal shape: {df_all.shape}")
df_all = df_all.dropna(how='all')  # Only drop rows where ALL values are NaN
print(f"After dropping fully NaN rows: {df_all.shape}")

# Fill any remaining NaNs with 0 (simple approach)
df_all = df_all.fillna(0)

# Prepare features and labels
X = df_all.drop(columns=LABELS)
y = df_all[LABELS]

# Feature scaling for MLP
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Train model
print("\nTraining MLP classifier...")
clf = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    max_iter=500,
    random_state=42,
    early_stopping=True,
    verbose=True
)
clf.fit(X_train, y_train)
# Out:
# Processing slp01a...
# Processing slp01b...
# Processing slp02a...
# Processing slp02b...
# Processing slp03...
# Processing slp04...
# Processing slp14...
# Processing slp16...
# Processing slp32...
# Processing slp37...
# Processing slp41...
# Processing slp45...
# Processing slp48...
# Processing slp59...
# Processing slp60...
# Processing slp61...
# Processing slp66...
# Processing slp67x...
#
# Original shape: (10274, 90)
# After dropping fully NaN rows: (10274, 90)
#
# Training MLP classifier...
# Iteration 1, loss = 6.84270595
# Validation score: 0.048662
# Iteration 2, loss = 3.92120533
# Validation score: 0.105839
# Iteration 3, loss = 3.59160290
# Validation score: 0.160584
# Iteration 4, loss = 3.41872099
# Validation score: 0.176399
# Iteration 5, loss = 3.29199339
# Validation score: 0.246959
# Iteration 6, loss = 3.19271302
# Validation score: 0.267640
# Iteration 7, loss = 3.11065879
# Validation score: 0.265207
# Iteration 8, loss = 3.04169034
# Validation score: 0.305353
# Iteration 9, loss = 2.98007238
# Validation score: 0.321168
# Iteration 10, loss = 2.92442863
# Validation score: 0.340633
# Iteration 11, loss = 2.87741031
# Validation score: 0.334550
# Iteration 12, loss = 2.83505031
# Validation score: 0.349148
# Iteration 13, loss = 2.79391553
# Validation score: 0.366180
# Iteration 14, loss = 2.76376914
# Validation score: 0.384428
# Iteration 15, loss = 2.72655699
# Validation score: 0.360097
# Iteration 16, loss = 2.70270975
# Validation score: 0.377129
# Iteration 17, loss = 2.67907066
# Validation score: 0.371046
# Iteration 18, loss = 2.64772872
# Validation score: 0.401460
# Iteration 19, loss = 2.61966209
# Validation score: 0.406326
# Iteration 20, loss = 2.59557419
# Validation score: 0.391727
# Iteration 21, loss = 2.57724491
# Validation score: 0.414842
# Iteration 22, loss = 2.55485748
# Validation score: 0.416058
# Iteration 23, loss = 2.53775589
# Validation score: 0.412409
# Iteration 24, loss = 2.52270369
# Validation score: 0.418491
# Iteration 25, loss = 2.49871944
# Validation score: 0.414842
# Iteration 26, loss = 2.48161195
# Validation score: 0.430657
# Iteration 27, loss = 2.46285837
# Validation score: 0.422141
# Iteration 28, loss = 2.45326746
# Validation score: 0.431873
# Iteration 29, loss = 2.43725794
# Validation score: 0.430657
# Iteration 30, loss = 2.42175191
# Validation score: 0.445255
# Iteration 31, loss = 2.39698505
# Validation score: 0.442822
# Iteration 32, loss = 2.39035785
# Validation score: 0.452555
# Iteration 33, loss = 2.37716145
# Validation score: 0.439173
# Iteration 34, loss = 2.36471301
# Validation score: 0.447689
# Iteration 35, loss = 2.36213329
# Validation score: 0.442822
# Iteration 36, loss = 2.34721316
# Validation score: 0.448905
# Iteration 37, loss = 2.33641740
# Validation score: 0.441606
# Iteration 38, loss = 2.32412842
# Validation score: 0.467153
# Iteration 39, loss = 2.32489005
# Validation score: 0.457421
# Iteration 40, loss = 2.29809556
# Validation score: 0.463504
# Iteration 41, loss = 2.29448125
# Validation score: 0.454988
# Iteration 42, loss = 2.29123587
# Validation score: 0.469586
# Iteration 43, loss = 2.28590062
# Validation score: 0.454988
# Iteration 44, loss = 2.26319770
# Validation score: 0.461071
# Iteration 45, loss = 2.25647117
# Validation score: 0.458637
# Iteration 46, loss = 2.24569092
# Validation score: 0.462287
# Iteration 47, loss = 2.23174569
# Validation score: 0.461071
# Iteration 48, loss = 2.23259230
# Validation score: 0.473236
# Iteration 49, loss = 2.22001276
# Validation score: 0.469586
# Iteration 50, loss = 2.20711393
# Validation score: 0.470803
# Iteration 51, loss = 2.20716039
# Validation score: 0.470803
# Iteration 52, loss = 2.19909437
# Validation score: 0.486618
# Iteration 53, loss = 2.18509379
# Validation score: 0.462287
# Iteration 54, loss = 2.17851141
# Validation score: 0.478102
# Iteration 55, loss = 2.17283011
# Validation score: 0.457421
# Iteration 56, loss = 2.16750757
# Validation score: 0.500000
# Iteration 57, loss = 2.16345868
# Validation score: 0.484185
# Iteration 58, loss = 2.16050139
# Validation score: 0.482968
# Iteration 59, loss = 2.15059939
# Validation score: 0.469586
# Iteration 60, loss = 2.14265604
# Validation score: 0.496350
# Iteration 61, loss = 2.14160557
# Validation score: 0.495134
# Iteration 62, loss = 2.12907627
# Validation score: 0.489051
# Iteration 63, loss = 2.12381025
# Validation score: 0.484185
# Iteration 64, loss = 2.11618229
# Validation score: 0.492701
# Iteration 65, loss = 2.10777162
# Validation score: 0.482968
# Iteration 66, loss = 2.10504020
# Validation score: 0.496350
# Iteration 67, loss = 2.10259017
# Validation score: 0.476886
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(128, 64), max_iter=500,
#               random_state=42, verbose=True)

# %%
y_pred = clf.predict(X_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=LABELS))

accuracies = (y_pred == y_test).mean(axis=0)
for label, acc in zip(LABELS, accuracies):
    print(f"Accuracy for {label}: {acc:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            H       0.66      0.26      0.37       203
#           HA       0.63      0.28      0.39       150
#           OA       0.75      0.74      0.75       133
#            X       0.68      0.59      0.63       304
#           CA       0.33      0.02      0.04        47
#          CAA       0.00      0.00      0.00        38
#            L       0.75      0.45      0.56        97
#           LA       0.54      0.51      0.53        37
#            A       0.70      0.45      0.55       368
#            W       0.79      0.80      0.79       622
#            1       0.65      0.31      0.42       340
#            2       0.78      0.71      0.74       783
#            3       0.67      0.44      0.53       109
#            4       0.75      0.47      0.58        38
#            R       0.87      0.61      0.72       151
#
#    micro avg       0.74      0.56      0.64      3420
#    macro avg       0.64      0.44      0.51      3420
# weighted avg       0.72      0.56      0.62      3420
#  samples avg       0.64      0.61      0.61      3420
#
# Accuracy for H: 0.91
# Accuracy for HA: 0.94
# Accuracy for OA: 0.97
# Accuracy for X: 0.90
# Accuracy for CA: 0.98
# Accuracy for CAA: 0.98
# Accuracy for L: 0.97
# Accuracy for LA: 0.98
# Accuracy for A: 0.87
# Accuracy for W: 0.87
# Accuracy for 1: 0.86
# Accuracy for 2: 0.81
# Accuracy for 3: 0.96
# Accuracy for 4: 0.99
# Accuracy for R: 0.96
# c:\Users\prana\anaconda3\envs\tds\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\prana\anaconda3\envs\tds\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import joblib

joblib.dump(clf, 'stacking_model.pkl')
print("✅ Model saved as 'stacking_model.pkl'")
# Out:
# ✅ Model saved as 'stacking_model.pkl'

# %%
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(X.columns.tolist(), 'feature_columns.pkl')
# Out:
# ['feature_columns.pkl']
